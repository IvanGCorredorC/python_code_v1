# %%
import pandas as pd
import numpy as np

# %%
icfes = pd.read_csv("C:/Users/Estadistico/Desktop/11042022_DEF_SABER1120212", sep= "[¬]", engine="python", encoding= "UTF-8")

# %%
icfes.describe()
# Out:
#                EDAD        DISCAP           HV5        VICTIMA     NO_VICTIMA  \
# count  91435.000000  91435.000000  91435.000000  541490.000000  541490.000000
# mean      18.924247      0.017455      1.142724       0.168858       0.831142
# std        2.670038      0.130960      0.430067       0.374627       0.374627
# min        0.670105      0.000000      1.000000       0.000000       0.000000
# 25%       17.790653      0.000000      1.000000       0.000000       1.000000
# 50%       18.374215      0.000000      1.000000       0.000000       1.000000
# 75%       19.300242      0.000000      1.000000       0.000000       1.000000
# max       74.998872      1.000000     20.000000       1.000000       1.000000
#
#          PUNT_GLOBAL  PERCENTIL_GLOBAL
# count  541490.000000     535371.000000
# mean      245.842418         49.989454
# std        50.636364         28.940072
# min         0.000000          1.000000
# 25%       207.000000         25.000000
# ...

# %%
pd.options.display.max_columns = None

# %%
print(icfes["ESTU_ESTUDIANTE "].value_counts())
# Out:
# ESTUDIANTE     541481
# INDIVIDUAL      64548
# Name: ESTU_ESTUDIANTE , dtype: int64

# %%
icfes.head()
# Out:
#    PERIODO  ESTU_PRIMERNOMBRE  ESTU_SEGUNDONOMBRE  ESTU_PRIMERAPELLIDO   \
# 0     20214             JHOAN             ALBERTO            DE LA HOZ
# 1     20214           ANGELLY               PAOLA             GONZALEZ
# 2     20214           MARIANA                                    ROJAS
# 3     20214            NEISER              MANUEL               OCAMPO
# 4     20214             MARIA                JOSE              GALEANO
#
#   ESTU_SEGUNDOAPELLIDO  ESTU_TIPODOCUMENTO  ESTU_DOCUMENTO   \
# 0               MATUTE                  TI      1043848296
# 1               DAVILA                  TI      1193046102
# 2            GUTIERREZ                  TI      1114238612
# 3                ORTIZ                  CC      1007205798
# 4              MENDOZA                  TI      1013456855
#
#   ESTU_NACIONALIDAD  ESTU_GENERO  ESTU_FECHANACIMIENTO   ESTU_CONSECUTIVO   \
# 0          COLOMBIA            M            08/06/2004   SB11202140611115
# ...

# %%
icfes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606029 entries, 0 to 606028
# Data columns (total 81 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   PERIODO                         606029 non-null  int64
#  1   ESTU_PRIMERNOMBRE               606029 non-null  object
#  2   ESTU_SEGUNDONOMBRE              606029 non-null  object
#  3   ESTU_PRIMERAPELLIDO             606029 non-null  object
#  4   ESTU_SEGUNDOAPELLIDO            606029 non-null  object
#  5   ESTU_TIPODOCUMENTO              606029 non-null  object
#  6   ESTU_DOCUMENTO                  606029 non-null  object
#  7   ESTU_NACIONALIDAD               606029 non-null  object
#  8   ESTU_GENERO                     606029 non-null  object
#  9   ESTU_FECHANACIMIENTO            606029 non-null  object
#  10  ESTU_CONSECUTIVO                606029 non-null  object
#  11  ESTU_ESTUDIANTE                 606029 non-null  object
# ...

# %%
msk_1 = icfes["ESTU_ESTUDIANTE "] == "ESTUDIANTE "
icfes_est = icfes[msk_1==True]

# %%
icfes_est.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 541481 entries, 0 to 606028
# Data columns (total 81 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   PERIODO                         541481 non-null  int64
#  1   ESTU_PRIMERNOMBRE               541481 non-null  object
#  2   ESTU_SEGUNDONOMBRE              541481 non-null  object
#  3   ESTU_PRIMERAPELLIDO             541481 non-null  object
#  4   ESTU_SEGUNDOAPELLIDO            541481 non-null  object
#  5   ESTU_TIPODOCUMENTO              541481 non-null  object
#  6   ESTU_DOCUMENTO                  541481 non-null  object
#  7   ESTU_NACIONALIDAD               541481 non-null  object
#  8   ESTU_GENERO                     541481 non-null  object
#  9   ESTU_FECHANACIMIENTO            541481 non-null  object
#  10  ESTU_CONSECUTIVO                541481 non-null  object
#  11  ESTU_ESTUDIANTE                 541481 non-null  object
# ...

# %%
icfes_est.to_csv("C:/Users/Estadistico/Desktop/BACKUP_07_07_2022/ivan/informes/bases/ICFES_SABER_11_20212.CSV", sep= ";")
