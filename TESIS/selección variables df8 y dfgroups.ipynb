# %%
import pandas as pd
#pip install pandas --upgrade
#pd.__version__
import numpy as np
#np.__version__
# from pandas_profiling import ProfileReport
import dtale
#from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-eb8844fa916b> in <module>
#       8 #from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler
#       9 import statsmodels.api as sm
# ---> 10 import linearmodels as lm
#
# ModuleNotFoundError: No module named 'linearmodels'

# %%
# %run ./bases_datos_tesis.ipynb

# %% [markdown]
# ### df7 --> df8

# %%
d = dtale.show(df8, ignore_duplicate = True)
d
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-32LNM716:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#variables que contiene
len(df7.columns.to_list())
# Out:
# 205

# %%
len(df8.columns.to_list())
# Out:
# 160

# %%
#variables para el modelo (subset)
df8 = df7[[
#control 
 'Fecha',
 'ano_encuesta',
 'id',
 'ola_l',
 'hogar_numero',
 'orden',
 'seguimiento',
 #ubicación
 'region_encuesta',
 'id_mpioU',
  #condiciones sociodemográficas
 'sexo',
 'edad',
 'rango_edad',
 'edad_meses',
 'parentesco',
 'estado_civil',
 'vive_conyuge',
 'orden_conyuge',
 'etnia',
 #condiciones socieconómicas:  
 'estrato',
 ##educación
 'lee_escribe',
 'estudia',
 'educación',
 'educación2',
 'edad_dejoestudio',
 'anos_superior',
 'anos_superior2', 
 ##clasificación laboral
     ###ocupados  
 'clasif_lab',
 'actividad_ppal',
 ### desocupados
 'diligencias4',
 'diligencias12',
 #inactivos
 'actividad_principal',
 ###características de los ocupados
 'ocupacion',
 'ocupacion2',
 'cod_oficio',
 'cod_oficio2',
 'descrip_oficio',
 'descripcion_ciiu',
 'horas_normal',
 'horas_normal_2',
 'tipo_contrato',
 'tiempo_empleo',
 'not_null_empl',
 ### remuneraciones
 'Ingreso_total',
 'Ingreso_laboral',
 'Ingreso_no_laboral',
 'q_Ingreso_total',
 'q_Ingreso_laboral',
 'q_Ingreso_no_laboral',
 'rec_otros_pago',
 'vr_alimentos_pago',
 'vr_vivienda_pago',
 'vr_educ_pago',
 'vr_subalimentacion',
 'vr_subtransporte',
 'vr_subfamiliar',
 'vr_bonos',
 'vr_ingmen_ase',
 'vr_salario',
 'vr_ganancia',
 'vr_ganancia_2',
 'meses_ganancia',
 'rec_ninguno',
 'pagos_adicion',
 'ingresos',
 'ganancia_neta',
 'vr_salario_mes',
 'recibio_ganancia',
  ### calidad del empleo
 'segsoc_salud',
 'afiliacion_fp',
 'ta_empresa',
 'Tipo_empleo',
 'tipo_sector',
 'hussmanns',
 'hussmanns_a',
 'hussmanns_b',
 ####salud
 'afiliacion',
 'estaba_sss',
 'beneficiario_sss',
 'beneficiario_orden',
 'seg_medico',
 ####pensión
 'cotiza_fp',
 'cotiza_fp2',
 'estaba_fp',     
 'vr_rec_pension',
 ####tamaño
 'registro_mercantil',
  ####condiciones adicionales
 'vacaciones',
 'prima_navidad',
 'cesantias',
 ### características de los desocupados
 'tiempo_desempleo',
 'ofertas_empleo',
 'ofertas_emp12',
 'ofertas_emp1',
 'vr_salario_ofr',
 'razon_noacepto',
 'disponibilidad',
 't_bustrab_a',
 't_bustrab_m',
 'medio_busco',
 't_busco_trab_r',
 't_busco_trab_l',
 't_dejo_trabajar',
 'vr_rec_arriendos',
 'vr_rec_dividendos',
 'vr_rec_dividendos_2',
 'salario_insf',
 'salario_nopresta',
 'horario_nosirve',
 'ubica_inadecuada',
 'noapto_trabajo',
 'razon_personal',
  ## historia laboral
 ###caracterísicas ocupados
 'edad_primert',
 'anos_primert',
 'horas_normal_pt',
 'ocupacion_pt',
 'es_ptrabajo',
 't_trabajo_ult',
 'trabajo_ult3',
 'tiempo_trab',
 ###remuneración
 'vr_recibia_pt',
 'rango_ingreso',
 ###salud
 'sss_pt',
 ###pensión
 'afiliado_fp_pt',
 'cotizando',
 ###tamaño
 'tamano_pt',
  ###caracterísicas desocupados
 'desemp_ult3',
 'tiempo_desemp',
 'nocotiza_ult3',
 'tiempo_ncotiza',
 'primer_busca',
 #condiciones de la vivienda
 'tipo_vivienda',
 'material_pisos',
 'material_paredes',
 'sp_energia',
 'sp_estrato',
 'sp_gasnatural',
 'sp_acueducto',
 'sp_alcantarillado',
 'sp_telefono',
 'sp_recoleccion_basura',
 'eliminan_basura',
 #representatividad
 'riqueza_pca',
 'tercil',
 'factorex_hlong',
 'factorex_hola',
 'factorex_hlong_uni',
 'factorex_plong',
 'factorex_pola',
 'factorex_plong_uni',
 'scar_uno',
 'scar_dos',
 'scar_tres',
 'scar_cuatro',
 'scar_cinco',
 'scar_seis',
 'control_uno',
 'control_dos',
 'control_tres',
 'control_cuatro',
 'control_cinco',
 'control_seis'
  ]]

# %%
df8.to_csv('D:/maestria_ciencias_economicas_unal/tesis_scarring/base datos/ELCA_FINAL/PANEL_MODELO.csv', sep = ";")

# %% [markdown]
# ### dfprueba

# %%
dfp = dtale.show(dfgroups, ignore_duplicate = True)
dfp
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-32LNM716:40000/dtale/iframe/5"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
len(dfprueba.columns.to_list())
# Out:
# 208

# %%
len(dfgroups.columns.to_list())
# Out:
# 151

# %%
#variables que contiene
dfprueba.columns.to_list()
# Out:
# ['ola_l',
#  'hogar_l',
#  'hogar_n16_l',
#  'orden',
#  'seguimiento',
#  'encuestada_2013',
#  'region',
#  'RegionLb',
#  'region_2016',
#  'id_depto',
#  'id_mpio',
#  'id_mpioU',
#  'riqueza_pca',
#  'tercil2010',
#  'tercil2013',
#  'tercil2016',
#  'fhog',
#  'fhog_2010',
#  'fhog_2013',
#  'fhog_2016',
#  'fexhog',
#  'fexhog_2010',
#  'fexhog_2013',
#  'fpers',
#  'fpers_2010',
#  'fpers_2013',
#  'fpers_2016',
#  'fexpers',
#  'fexpers_2010',
#  'fexpers_2013',
#  't_hogares',
#  't_hogar',
#  't_personas',
#  'tipo_vivienda',
#  'material_pisos',
#  'material_paredes',
#  'sp_energia',
#  'sp_estrato',
#  'sp_gasnatural',
#  'sp_acueducto',
#  'sp_alcantarillado',
#  'sp_telefono',
#  'sp_recoleccion_basura',
#  'eliminan_basura',
#  'sexo',
#  'edad',
#  'edad_meses',
#  'parentesco',
#  'estado_civil',
#  'vive_conyuge',
#  'orden_conyuge',
#  'etnia',
#  'estrato',
#  'lee_escribe',
#  'estudia',
#  'nivel_educ',
#  'grado_educ',
#  'edad_dejoestudio',
#  'nivel_educ_cursa',
#  'grado_educ_cursa',
#  'anos_superior',
#  'estudiaba_2010',
#  'nivel_educ_2010',
#  'grado_educ_2010',
#  'anos_superior_2010',
#  'est_superiores',
#  'actividad_ppal',
#  'diligencias4',
#  'diligencias12',
#  'descripcion_ciiu',
#  'descrip_oficio',
#  'cod_oficio',
#  'edad_tenia',
#  'anos_trabaja',
#  'meses_trabaja',
#  'mes_inicio',
#  'ano_inicio',
#  'ocupacion',
#  'horas_normal',
#  'cod_oficio2',
#  'tipo_contrato',
#  'rec_otros_pago',
#  'vr_alimentos_pago',
#  'vr_vivienda_pago',
#  'vr_educ_pago',
#  'vr_subalimentacion',
#  'vr_subtransporte',
#  'vr_subfamiliar',
#  'vr_bonos',
#  'vr_ingmen_ase',
#  'vr_salario',
#  'vr_ganancia',
#  'meses_ganancia',
#  'rec_ninguno',
#  'pagos_adicion',
#  'ingresos',
#  'ganancia_neta',
#  'vr_salario_mes',
#  'recibio_ganancia',
#  'afiliacion',
#  'seg_medico',
#  'segsoc_salud',
#  'estaba_sss',
#  'beneficiario_sss',
#  'beneficiario_orden',
#  'cotiza_fp',
#  'estaba_fp',
#  'afiliacion_fp',
#  'vr_rec_pension',
#  'tam_empresa',
#  'n_empleados',
#  'registro_mercantil',
#  'vacaciones',
#  'prima_navidad',
#  'cesantias',
#  'ofertas_empleo',
#  'ofertas_emp12',
#  'ofertas_emp1',
#  'vr_salario_ofr',
#  'razon_noacepto',
#  'disponibilidad',
#  't_bustrab_a',
#  't_bustrab_m',
#  'medio_busco',
#  't_busco_trab_l',
#  't_dejo_trabajar',
#  'vr_rec_arriendos',
#  'vr_rec_dividendos',
#  'salario_insf',
#  'salario_nopresta',
#  'horario_nosirve',
#  'ubica_inadecuada',
#  'noapto_trabajo',
#  'razon_personal',
#  'edad_primert',
#  'anos_primert',
#  'horas_normal_pt',
#  'ocupacion_pt',
#  'es_ptrabajo',
#  't_trabajo_ult',
#  'trabajo_ult3',
#  'tiempo_trab',
#  'vr_recibia_pt',
#  'rango_ingreso',
#  'sss_pt',
#  'afiliado_fp_pt',
#  'cotizando',
#  'tamano_pt',
#  'desemp_ult3',
#  'tiempo_desemp',
#  'nocotiza_ult3',
#  'tiempo_ncotiza',
#  'primer_busca',
#  'clasif_lab',
#  'scar',
#  'scar_dos',
#  'scar_tres',
#  'scar_cuatro',
#  'scar_cinco',
#  'control_uno',
#  'control_dos',
#  'actividad_principal',
#  't_busco_trab_r',
#  'indicator_column',
#  'scar_seis',
#  'tiempo_desempleo',
#  'id',
#  'control_tres',
#  'control_cuatro',
#  'control_cinco',
#  'ano_encuesta',
#  'tiempo_empleo',
#  'control_seis',
#  'not_null_empl',
#  'rango_edad',
#  'Fecha',
#  'control',
#  'camino',
#  'scar_uno',
#  'ocupacion2',
#  'anos_superior2',
#  'horas_normal_2',
#  'Ingreso_laboral',
#  'vr_ganancia_2',
#  'vr_rec_dividendos_2',
#  'Ingreso_no_laboral',
#  'Ingreso_total',
#  'ta_empresa',
#  'educación',
#  'cotiza_fp2',
#  'educación2',
#  'Tipo_empleo',
#  'tipo_sector',
#  'hussmanns',
#  'hussmanns_a',
#  'hussmanns_b',
#  'q_Ingreso_laboral',
#  'q_Ingreso_no_laboral',
#  'q_Ingreso_total',
#  'hogar_numero',
#  'region_encuesta',
#  'tercil',
#  'factorex_hlong',
#  'factorex_hola',
#  'factorex_plong',
#  'factorex_pola',
#  'factorex_hlong_uni',
#  'factorex_plong_uni']

# %%
#variables para el modelo (subset)
dfgroups = dfprueba[[
#control 
 'Fecha',
 'ano_encuesta',
 'id',
 'ola_l',
 'hogar_numero',
 'orden',
 'seguimiento',
 #ubicación
 'region_encuesta',
 'id_mpioU',
  #condiciones sociodemográficas
 'sexo',
 'edad',
 'rango_edad',
 'edad_meses',
 'parentesco',
 'estado_civil',
 'vive_conyuge',
 'orden_conyuge',
 'etnia',
 #condiciones socieconómicas:  
 'estrato',
 ##educación
 'lee_escribe',
 'estudia',
 'educación',
 'educación2',
 'edad_dejoestudio',
 'anos_superior',
 'anos_superior2', 
 ##clasificación laboral
     ###ocupados  
 'clasif_lab',
 'actividad_ppal',
 ### desocupados
 'diligencias4',
 'diligencias12',
 #inactivos
 'actividad_principal',
 ###características de los ocupados
 'ocupacion',
 'ocupacion2',
 'cod_oficio',
 'cod_oficio2',
 'descrip_oficio',
 'descripcion_ciiu',
 'horas_normal',
 'horas_normal_2',
 'tipo_contrato',
 'tiempo_empleo',
 'not_null_empl',
 ### remuneraciones
 'Ingreso_total',
 'Ingreso_laboral',
 'Ingreso_no_laboral',
 'q_Ingreso_total',
 'q_Ingreso_laboral',
 'q_Ingreso_no_laboral',
 'rec_otros_pago',
 'vr_alimentos_pago',
 'vr_vivienda_pago',
 'vr_educ_pago',
 'vr_subalimentacion',
 'vr_subtransporte',
 'vr_subfamiliar',
 'vr_bonos',
 'vr_ingmen_ase',
 'vr_salario',
 'vr_ganancia',
 'vr_ganancia_2',
 'meses_ganancia',
 'rec_ninguno',
 'pagos_adicion',
 'ingresos',
 'ganancia_neta',
 'vr_salario_mes',
 'recibio_ganancia',
  ### calidad del empleo
 'segsoc_salud',
 'afiliacion_fp',
 'ta_empresa',
 'Tipo_empleo',
 'tipo_sector',
 'hussmanns',
 'hussmanns_a',
 'hussmanns_b',
 ####salud
 'afiliacion',
 'estaba_sss',
 'beneficiario_sss',
 'beneficiario_orden',
 'seg_medico',
 ####pensión
 'cotiza_fp',
 'cotiza_fp2',
 'estaba_fp',     
 'vr_rec_pension',
 ####tamaño
 'registro_mercantil',
  ####condiciones adicionales
 'vacaciones',
 'prima_navidad',
 'cesantias',
 ### características de los desocupados
 'tiempo_desempleo',
 'ofertas_empleo',
 'ofertas_emp12',
 'ofertas_emp1',
 'vr_salario_ofr',
 'razon_noacepto',
 'disponibilidad',
 't_bustrab_a',
 't_bustrab_m',
 'medio_busco',
 't_busco_trab_r',
 't_busco_trab_l',
 't_dejo_trabajar',
 'vr_rec_arriendos',
 'vr_rec_dividendos',
 'vr_rec_dividendos_2',
 'salario_insf',
 'salario_nopresta',
 'horario_nosirve',
 'ubica_inadecuada',
 'noapto_trabajo',
 'razon_personal',
  ## historia laboral
 ###caracterísicas ocupados
 'edad_primert',
 'anos_primert',
 'horas_normal_pt',
 'ocupacion_pt',
 'es_ptrabajo',
 't_trabajo_ult',
 'trabajo_ult3',
 'tiempo_trab',
 ###remuneración
 'vr_recibia_pt',
 'rango_ingreso',
 ###salud
 'sss_pt',
 ###pensión
 'afiliado_fp_pt',
 'cotizando',
 ###tamaño
 'tamano_pt',
  ###caracterísicas desocupados
 'desemp_ult3',
 'tiempo_desemp',
 'nocotiza_ult3',
 'tiempo_ncotiza',
 'primer_busca',
 #condiciones de la vivienda
 'tipo_vivienda',
 'material_pisos',
 'material_paredes',
 'sp_energia',
 'sp_estrato',
 'sp_gasnatural',
 'sp_acueducto',
 'sp_alcantarillado',
 'sp_telefono',
 'sp_recoleccion_basura',
 'eliminan_basura',
 #representatividad
 'riqueza_pca',
 'tercil',
 'factorex_hlong',
 'factorex_hola',
 'factorex_hlong_uni',
 'factorex_plong',
 'factorex_pola',
 'factorex_plong_uni',
 'scar',
  'control',
  'camino']]

# %%
dfgroups.to_csv('D:/maestria_ciencias_economicas_unal/tesis_scarring/base datos/ELCA_FINAL/Trat_ctrl_MODELO.csv', sep = ";")
